# %%
import pandas as pd

df = pd.read_csv("../data/processed/transcripts.csv")
df.head()
# Out:
#                      doc_path   company_hint  fiscal_year fiscal_quarter  \
# 0  data/raw/SAMPLE_2024Q2.txt  SAMPLE 2024Q2         2024             Q2
# 1  data/raw/SAMPLE_2024Q2.txt  SAMPLE 2024Q2         2024             Q2
# 2  data/raw/SAMPLE_2024Q2.txt  SAMPLE 2024Q2         2024             Q2
#
#   ingest_date  segment_index   speaker           section  \
# 0  2025-11-23              0  OPERATOR  prepared_remarks
# 1  2025-11-23              1       CFO  prepared_remarks
# 2  2025-11-23              2       Q&A                qa
#
#                                text       source
# 0       Welcome to Q2 2024 results.  manual_drop
# 1  Revenue grew 10% year-over-year.  manual_drop
# 2      Analyst: What about margins?  manual_drop

# %%
df.columns, len(df)
# Out:
# (Index(['doc_path', 'company_hint', 'fiscal_year', 'fiscal_quarter',
#         'ingest_date', 'segment_index', 'speaker', 'section', 'text', 'source'],
#        dtype='object'),
#  3)

# %%
df["speaker"].unique(), df["section"].unique()
# Out:
# (array(['OPERATOR', 'CFO', 'Q&A'], dtype=object),
#  array(['prepared_remarks', 'qa'], dtype=object))

# %%
df.iloc[0]["text"]
# Out:
# 'Welcome to Q2 2024 results.'
